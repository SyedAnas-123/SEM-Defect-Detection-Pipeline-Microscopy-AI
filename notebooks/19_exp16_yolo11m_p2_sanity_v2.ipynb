# %% [markdown]
# # Phase 16: YOLO11m + P2 Head (Sanity Run V2)
#
# This notebook dynamically creates the corrected `yolo11-p2.yaml` architecture (with `m: [0.50, 1.00, 512]`), loads `yolo11m.pt` weights (verifying transfer), and runs a 3-epoch sanity training to ensure mathematically correct operation on the Tesla T4 without OOM.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install dependencies
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.153-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=3.1.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.1.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.32.5)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.13/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.32 (from ultralytics)
#   Downloading ultralytics_platform-0.1.41-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.13/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.23.0->ultralytics) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: httpx<1,>=0.28 in /usr/local/lib/python3.13/dist-packages (from ultralytics-platform>=0.1.32->ultralytics) (0.28.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.32->ultralytics) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.32->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.32->ultralytics) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.153-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.3 MB/s eta 0:00:0000:01
# Downloading ultralytics_platform-0.1.41-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: ultralytics-platform, ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.153 ultralytics-platform-0.1.41 ultralytics-thop-2.1.6

# %%
import os
import torch
from ultralytics import YOLO

PROJECT_ROOT = '/content/drive/MyDrive/sem_defect_project'
os.chdir(PROJECT_ROOT)
print(f"Current working directory: {os.getcwd()}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Current working directory: /content/drive/MyDrive/sem_defect_project
# CUDA Available: True
# GPU Device: Tesla T4

# %%
# Create Custom yolo11-p2.yaml (FIXED V2)
yaml_content = '''
# YOLO11-P2 (Stride-4 High Resolution Head)
nc: 1
scales:
  # [depth, width, max_channels]
  m: [0.50, 1.00, 512] # CORRECTED YOLO11m scale

backbone:
  # [from, repeats, module, args]
  - [-1, 1, Conv, [64, 3, 2]] # 0-P1/2
  - [-1, 1, Conv, [128, 3, 2]] # 1-P2/4
  - [-1, 2, C3k2, [256, False, 0.25]] # 2
  - [-1, 1, Conv, [256, 3, 2]] # 3-P3/8
  - [-1, 2, C3k2, [512, False, 0.25]] # 4
  - [-1, 1, Conv, [512, 3, 2]] # 5-P4/16
  - [-1, 2, C3k2, [512, True]] # 6
  - [-1, 1, Conv, [1024, 3, 2]] # 7-P5/32
  - [-1, 2, C3k2, [1024, True]] # 8
  - [-1, 1, SPPF, [1024, 5]] # 9
  - [-1, 2, C2PSA, [1024]] # 10

head:
  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 6], 1, Concat, [1]] # cat backbone P4
  - [-1, 2, C3k2, [512, False]] # 13

  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 4], 1, Concat, [1]] # cat backbone P3
  - [-1, 2, C3k2, [256, False]] # 16 (P3/8-small)

  # --- P2 EXTENSION ---
  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 2], 1, Concat, [1]] # cat backbone P2
  - [-1, 2, C3k2, [128, False]] # 19 (P2/4-tiny)

  - [-1, 1, Conv, [128, 3, 2]]
  - [[-1, 16], 1, Concat, [1]] # cat head P3
  - [-1, 2, C3k2, [256, False]] # 22 (P3/8-small)

  - [-1, 1, Conv, [256, 3, 2]]
  - [[-1, 13], 1, Concat, [1]] # cat head P4
  - [-1, 2, C3k2, [512, False]] # 25 (P4/16-medium)

  - [-1, 1, Conv, [512, 3, 2]]
  - [[-1, 10], 1, Concat, [1]] # cat head P5
  - [-1, 2, C3k2, [1024, True]] # 28 (P5/32-large)

  - [[19, 22, 25, 28], 1, Detect, [nc]] # Detect(P2, P3, P4, P5)
'''

with open('yolo11-p2.yaml', 'w') as f:
    f.write(yaml_content)

print("Created yolo11-p2.yaml successfully (V2 Corrected)!")
# Out:
# Created yolo11-p2.yaml successfully (V2 Corrected)!

# %%
# Instantiate Model and Load Weights
print("Instantiating YOLO11m-P2 model...")
model = YOLO('yolo11-p2.yaml')

print("\nLoading pretrained YOLO11m weights into P2 architecture...")
# Load weights, matching shapes automatically
model.load('yolo11m.pt')

# Print full architecture summary to verify P2/P3/P4/P5 shapes
model.info(detailed=True)
# Out:
# Instantiating YOLO11m-P2 model...
# WARNING ⚠️ no model scale passed. Assuming scale='m'.
#
# Loading pretrained YOLO11m weights into P2 architecture...
# Transferred 427/803 items from pretrained weights
# layer                                    name                type  gradient  parameters               shape        mu     sigma
#     0                     model.0.conv.weight              Conv2d      True        1728       [64, 3, 3, 3] -0.000858     0.102        float32
#     1                       model.0.bn.weight         BatchNorm2d      True          64                [64]      4.28      1.16        float32
#     1                         model.0.bn.bias         BatchNorm2d      True          64                [64]     0.245      1.93        float32
#     2                             model.0.act                SiLU     False           0                  []         -         -              -
#     3                     model.1.conv.weight              Conv2d      True       73728     [128, 64, 3, 3] -0.000476    0.0173        float32
#     4                       model.1.bn.weight         BatchNorm2d      True         128               [128]      2.67     0.688        float32
#     4                         model.1.bn.bias         BatchNorm2d      True         128               [128]     0.632      1.31        float32
#     5                 model.2.cv1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]  -0.00209    0.0246        float32
#     6                   model.2.cv1.bn.weight         BatchNorm2d      True         128               [128]      1.64     0.652        float32
#     6                     model.2.cv1.bn.bias         BatchNorm2d      True         128               [128]     0.394      0.97        float32
#     7                 model.2.cv2.conv.weight              Conv2d      True       49152    [256, 192, 1, 1]  -0.00161    0.0168        float32
#     8                   model.2.cv2.bn.weight         BatchNorm2d      True         256               [256]     0.954     0.262        float32
#     8                     model.2.cv2.bn.bias         BatchNorm2d      True         256               [256]    -0.862     0.646        float32
#     9             model.2.m.0.cv1.conv.weight              Conv2d      True        2048      [32, 64, 1, 1]  -0.00262    0.0298        float32
#    10               model.2.m.0.cv1.bn.weight         BatchNorm2d      True          32                [32]     0.674     0.465        float32
#    10                 model.2.m.0.cv1.bn.bias         BatchNorm2d      True          32                [32]     0.426     0.776        float32
#    11             model.2.m.0.cv2.conv.weight              Conv2d      True        2048      [32, 64, 1, 1]  -0.00195    0.0205        float32
#    12               model.2.m.0.cv2.bn.weight         BatchNorm2d      True          32                [32]      1.49     0.402        float32
#    12                 model.2.m.0.cv2.bn.bias         BatchNorm2d      True          32                [32]    -0.435     0.452        float32
#    13             model.2.m.0.cv3.conv.weight              Conv2d      True        4096      [64, 64, 1, 1] -0.000402    0.0268        float32
#    14               model.2.m.0.cv3.bn.weight         BatchNorm2d      True          64                [64]      1.51     0.315        float32
#    14                 model.2.m.0.cv3.bn.bias         BatchNorm2d      True          64                [64]     0.474     0.888        float32
#    15         model.2.m.0.m.0.cv1.conv.weight              Conv2d      True        9216      [32, 32, 3, 3] -0.000254    0.0204        float32
#    16           model.2.m.0.m.0.cv1.bn.weight         BatchNorm2d      True          32                [32]      1.16     0.311        float32
#    16             model.2.m.0.m.0.cv1.bn.bias         BatchNorm2d      True          32                [32]     0.114      1.06        float32
#    17         model.2.m.0.m.0.cv2.conv.weight              Conv2d      True        9216      [32, 32, 3, 3]  -0.00174    0.0172        float32
#    18           model.2.m.0.m.0.cv2.bn.weight         BatchNorm2d      True          32                [32]     0.668     0.251        float32
#    18             model.2.m.0.m.0.cv2.bn.bias         BatchNorm2d      True          32                [32]     0.703     0.821        float32
#    19         model.2.m.0.m.1.cv1.conv.weight              Conv2d      True        9216      [32, 32, 3, 3] -0.000544    0.0184        float32
#    20           model.2.m.0.m.1.cv1.bn.weight         BatchNorm2d      True          32                [32]     0.778     0.242        float32
#    20             model.2.m.0.m.1.cv1.bn.bias         BatchNorm2d      True          32                [32]   -0.0935     0.969        float32
#    21         model.2.m.0.m.1.cv2.conv.weight              Conv2d      True        9216      [32, 32, 3, 3] -0.000319    0.0182        float32
#    22           model.2.m.0.m.1.cv2.bn.weight         BatchNorm2d      True          32                [32]     0.727     0.189        float32
#    22             model.2.m.0.m.1.cv2.bn.bias         BatchNorm2d      True          32                [32]      1.33     0.759        float32
#    23                     model.3.conv.weight              Conv2d      True      589824    [256, 256, 3, 3] -0.000259   0.00712        float32
#    24                       model.3.bn.weight         BatchNorm2d      True         256               [256]     0.758     0.243        float32
#    24                         model.3.bn.bias         BatchNorm2d      True         256               [256]    -0.402     0.887        float32
#    25                 model.4.cv1.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -0.000639    0.0147        float32
#    26                   model.4.cv1.bn.weight         BatchNorm2d      True         256               [256]     0.683     0.208        float32
#    26                     model.4.cv1.bn.bias         BatchNorm2d      True         256               [256]    -0.025     0.671        float32
#    27                 model.4.cv2.conv.weight              Conv2d      True      196608    [512, 384, 1, 1] -0.000903    0.0108        float32
#    28                   model.4.cv2.bn.weight         BatchNorm2d      True         512               [512]     0.887     0.203        float32
#    28                     model.4.cv2.bn.bias         BatchNorm2d      True         512               [512]    -0.946     0.556        float32
#    29             model.4.m.0.cv1.conv.weight              Conv2d      True        8192     [64, 128, 1, 1]  -0.00191    0.0177        float32
#    30               model.4.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]     0.436     0.153        float32
#    30                 model.4.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]     0.178     0.516        float32
#    31             model.4.m.0.cv2.conv.weight              Conv2d      True        8192     [64, 128, 1, 1] -0.000893     0.011        float32
#    32               model.4.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]      1.05     0.172        float32
#    32                 model.4.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]     -0.45     0.233        float32
#    33             model.4.m.0.cv3.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]  -0.00111    0.0163        float32
#    34               model.4.m.0.cv3.bn.weight         BatchNorm2d      True         128               [128]     0.944     0.183        float32
#    34                 model.4.m.0.cv3.bn.bias         BatchNorm2d      True         128               [128]     -0.32     0.553        float32
#    35         model.4.m.0.m.0.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000658    0.0115        float32
#    36           model.4.m.0.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]     0.886     0.102        float32
#    36             model.4.m.0.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]    -0.872     0.535        float32
#    37         model.4.m.0.m.0.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000593    0.0108        float32
#    38           model.4.m.0.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]     0.692     0.185        float32
#    38             model.4.m.0.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]   -0.0689      0.53        float32
#    39         model.4.m.0.m.1.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000792    0.0117        float32
#    40           model.4.m.0.m.1.cv1.bn.weight         BatchNorm2d      True          64                [64]     0.766     0.153        float32
#    40             model.4.m.0.m.1.cv1.bn.bias         BatchNorm2d      True          64                [64]    -0.602     0.651        float32
#    41         model.4.m.0.m.1.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000279    0.0115        float32
#    42           model.4.m.0.m.1.cv2.bn.weight         BatchNorm2d      True          64                [64]     0.879     0.166        float32
#    42             model.4.m.0.m.1.cv2.bn.bias         BatchNorm2d      True          64                [64]      1.08     0.712        float32
#    43                     model.5.conv.weight              Conv2d      True  2.3593e+06    [512, 512, 3, 3] -9.26e-05   0.00415        float32
#    44                       model.5.bn.weight         BatchNorm2d      True         512               [512]     0.869      0.17        float32
#    44                         model.5.bn.bias         BatchNorm2d      True         512               [512]    -0.712      0.44        float32
#    45                 model.6.cv1.conv.weight              Conv2d      True      262144    [512, 512, 1, 1] -0.000857    0.0087        float32
#    46                   model.6.cv1.bn.weight         BatchNorm2d      True         512               [512]     0.938     0.147        float32
#    46                     model.6.cv1.bn.bias         BatchNorm2d      True         512               [512]    -0.699     0.421        float32
#    47                 model.6.cv2.conv.weight              Conv2d      True      393216    [512, 768, 1, 1]  -0.00063     0.008        float32
#    48                   model.6.cv2.bn.weight         BatchNorm2d      True         512               [512]      1.05     0.139        float32
#    48                     model.6.cv2.bn.bias         BatchNorm2d      True         512               [512]     -1.06     0.476        float32
#    49             model.6.m.0.cv1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]  -0.00111    0.0111        float32
#    50               model.6.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]     0.533      0.12        float32
#    50                 model.6.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]   0.00143     0.505        float32
#    51             model.6.m.0.cv2.conv.weight              Conv2d      True       32768    [128, 256, 1, 1] -0.000637    0.0068        float32
#    52               model.6.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.11     0.127        float32
#    52                 model.6.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]    -0.282     0.116        float32
#    53             model.6.m.0.cv3.conv.weight              Conv2d      True       65536    [256, 256, 1, 1]  -0.00105      0.01        float32
#    54               model.6.m.0.cv3.bn.weight         BatchNorm2d      True         256               [256]      1.15     0.141        float32
#    54                 model.6.m.0.cv3.bn.bias         BatchNorm2d      True         256               [256]     -0.67     0.277        float32
#    55         model.6.m.0.m.0.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000435   0.00618        float32
#    56           model.6.m.0.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]      1.04     0.119        float32
#    56             model.6.m.0.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.997      0.35        float32
#    57         model.6.m.0.m.0.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000456   0.00623        float32
#    58           model.6.m.0.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]     0.815      0.16        float32
#    58             model.6.m.0.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]    -0.416     0.348        float32
#    59         model.6.m.0.m.1.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3]  -0.00038   0.00713        float32
#    60           model.6.m.0.m.1.cv1.bn.weight         BatchNorm2d      True         128               [128]     0.929     0.142        float32
#    60             model.6.m.0.m.1.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.938     0.502        float32
#    61         model.6.m.0.m.1.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000178   0.00678        float32
#    62           model.6.m.0.m.1.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.39     0.217        float32
#    62             model.6.m.0.m.1.cv2.bn.bias         BatchNorm2d      True         128               [128]     0.277     0.465        float32
#    63                     model.7.conv.weight              Conv2d      True  2.3593e+06    [512, 512, 3, 3] -0.000124    0.0034        float32
#    64                       model.7.bn.weight         BatchNorm2d      True         512               [512]         1     0.158        float32
#    64                         model.7.bn.bias         BatchNorm2d      True         512               [512]    -0.657      0.35        float32
#    65                 model.8.cv1.conv.weight              Conv2d      True      262144    [512, 512, 1, 1] -0.000648   0.00689        float32
#    66                   model.8.cv1.bn.weight         BatchNorm2d      True         512               [512]      1.12      0.12        float32
#    66                     model.8.cv1.bn.bias         BatchNorm2d      True         512               [512]    -0.412     0.379        float32
#    67                 model.8.cv2.conv.weight              Conv2d      True      393216    [512, 768, 1, 1] -0.000499   0.00575        float32
#    68                   model.8.cv2.bn.weight         BatchNorm2d      True         512               [512]      1.16      0.21        float32
#    68                     model.8.cv2.bn.bias         BatchNorm2d      True         512               [512]    -0.146     0.307        float32
#    69             model.8.m.0.cv1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]    -0.001    0.0081        float32
#    70               model.8.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]     0.794     0.186        float32
#    70                 model.8.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.252     0.557        float32
#    71             model.8.m.0.cv2.conv.weight              Conv2d      True       32768    [128, 256, 1, 1] -0.000351   0.00436        float32
#    72               model.8.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.03    0.0391        float32
#    72                 model.8.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]    -0.164    0.0509        float32
#    73             model.8.m.0.cv3.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -0.000489   0.00678        float32
#    74               model.8.m.0.cv3.bn.weight         BatchNorm2d      True         256               [256]      1.19     0.162        float32
#    74                 model.8.m.0.cv3.bn.bias         BatchNorm2d      True         256               [256]    -0.229     0.286        float32
#    75         model.8.m.0.m.0.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000326   0.00483        float32
#    76           model.8.m.0.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]      1.24     0.128        float32
#    76             model.8.m.0.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.575     0.391        float32
#    77         model.8.m.0.m.0.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000289   0.00487        float32
#    78           model.8.m.0.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.17     0.246        float32
#    78             model.8.m.0.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]    -0.295     0.403        float32
#    79         model.8.m.0.m.1.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000341   0.00482        float32
#    80           model.8.m.0.m.1.cv1.bn.weight         BatchNorm2d      True         128               [128]      1.21     0.139        float32
#    80             model.8.m.0.m.1.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.633     0.323        float32
#    81         model.8.m.0.m.1.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000199   0.00462        float32
#    82           model.8.m.0.m.1.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.52     0.287        float32
#    82             model.8.m.0.m.1.cv2.bn.bias         BatchNorm2d      True         128               [128]      0.01     0.241        float32
#    83                 model.9.cv1.conv.weight              Conv2d      True      131072    [256, 512, 1, 1]  -0.00112   0.00851        float32
#    84                   model.9.cv1.bn.weight         BatchNorm2d      True         256               [256]     0.883     0.128        float32
#    84                     model.9.cv1.bn.bias         BatchNorm2d      True         256               [256]      1.03     0.356        float32
#    85                 model.9.cv2.conv.weight              Conv2d      True      524288   [512, 1024, 1, 1] -4.89e-06   0.00583        float32
#    86                   model.9.cv2.bn.weight         BatchNorm2d      True         512               [512]       1.1      0.24        float32
#    86                     model.9.cv2.bn.bias         BatchNorm2d      True         512               [512]    -0.646     0.545        float32
#    87                               model.9.m           MaxPool2d     False           0                  []         -         -              -
#    88                model.10.cv1.conv.weight              Conv2d      True      262144    [512, 512, 1, 1] -0.000613   0.00801        float32
#    89                  model.10.cv1.bn.weight         BatchNorm2d      True         512               [512]      1.35     0.287        float32
#    89                    model.10.cv1.bn.bias         BatchNorm2d      True         512               [512]    -0.133     0.407        float32
#    90                model.10.cv2.conv.weight              Conv2d      True      262144    [512, 512, 1, 1] -0.000507   0.00781        float32
#    91                  model.10.cv2.bn.weight         BatchNorm2d      True         512               [512]     0.997     0.192        float32
#    91                    model.10.cv2.bn.bias         BatchNorm2d      True         512               [512]    -0.835     0.417        float32
#    92       model.10.m.0.attn.qkv.conv.weight              Conv2d      True      131072    [512, 256, 1, 1] -3.13e-05    0.0102        float32
#    93         model.10.m.0.attn.qkv.bn.weight         BatchNorm2d      True         512               [512]      1.19     0.304        float32
#    93           model.10.m.0.attn.qkv.bn.bias         BatchNorm2d      True         512               [512]  -0.00923     0.271        float32
#    94               model.10.m.0.attn.qkv.act            Identity     False           0                  []         -         -              -
#    95      model.10.m.0.attn.proj.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -1.54e-05   0.00948        float32
#    96        model.10.m.0.attn.proj.bn.weight         BatchNorm2d      True         256               [256]     0.909     0.142        float32
#    96          model.10.m.0.attn.proj.bn.bias         BatchNorm2d      True         256               [256]  3.01e-06   2.3e-05        float32
#    97              model.10.m.0.attn.proj.act            Identity     False           0                  []         -         -              -
#    98        model.10.m.0.attn.pe.conv.weight              Conv2d      True        2304      [256, 1, 3, 3]  -0.00893    0.0203        float32
#    99          model.10.m.0.attn.pe.bn.weight         BatchNorm2d      True         256               [256]     0.711     0.275        float32
#    99            model.10.m.0.attn.pe.bn.bias         BatchNorm2d      True         256               [256]  4.23e-06  3.29e-05        float32
#   100                model.10.m.0.attn.pe.act            Identity     False           0                  []         -         -              -
#   101          model.10.m.0.ffn.0.conv.weight              Conv2d      True      131072    [512, 256, 1, 1] -0.000203   0.00624        float32
#   102            model.10.m.0.ffn.0.bn.weight         BatchNorm2d      True         512               [512]       1.2     0.131        float32
#   102              model.10.m.0.ffn.0.bn.bias         BatchNorm2d      True         512               [512]    -0.449     0.167        float32
#   103          model.10.m.0.ffn.1.conv.weight              Conv2d      True      131072    [256, 512, 1, 1]  6.53e-05   0.00524        float32
#   104            model.10.m.0.ffn.1.bn.weight         BatchNorm2d      True         256               [256]     0.679     0.159        float32
#   104              model.10.m.0.ffn.1.bn.bias         BatchNorm2d      True         256               [256]  1.81e-06  1.75e-05        float32
#   105                  model.10.m.0.ffn.1.act            Identity     False           0                  []         -         -              -
#   106                                model.11            Upsample     False           0                  []         -         -              -
#   107                                model.12              Concat     False           0                  []         -         -              -
#   108                model.13.cv1.conv.weight              Conv2d      True      524288   [512, 1024, 1, 1] -0.000556   0.00804        float32
#   109                  model.13.cv1.bn.weight         BatchNorm2d      True         512               [512]      0.94     0.189        float32
#   109                    model.13.cv1.bn.bias         BatchNorm2d      True         512               [512]    -0.843     0.618        float32
#   110                model.13.cv2.conv.weight              Conv2d      True      393216    [512, 768, 1, 1] -0.000721   0.00781        float32
#   111                  model.13.cv2.bn.weight         BatchNorm2d      True         512               [512]     0.804     0.169        float32
#   111                    model.13.cv2.bn.bias         BatchNorm2d      True         512               [512]     -0.78     0.487        float32
#   112            model.13.m.0.cv1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]  -0.00122    0.0121        float32
#   113              model.13.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]     0.586     0.166        float32
#   113                model.13.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.367     0.588        float32
#   114            model.13.m.0.cv2.conv.weight              Conv2d      True       32768    [128, 256, 1, 1] -0.000912   0.00806        float32
#   115              model.13.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.31     0.129        float32
#   115                model.13.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]    -0.351     0.143        float32
#   116            model.13.m.0.cv3.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -0.000733   0.00946        float32
#   117              model.13.m.0.cv3.bn.weight         BatchNorm2d      True         256               [256]     0.929     0.138        float32
#   117                model.13.m.0.cv3.bn.bias         BatchNorm2d      True         256               [256]     -0.59      0.34        float32
#   118        model.13.m.0.m.0.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3]  -0.00044   0.00714        float32
#   119          model.13.m.0.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]         1     0.165        float32
#   119            model.13.m.0.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.799     0.594        float32
#   120        model.13.m.0.m.0.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000369   0.00648        float32
#   121          model.13.m.0.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.04     0.235        float32
#   121            model.13.m.0.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]   -0.0593     0.598        float32
#   122        model.13.m.0.m.1.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000388   0.00612        float32
#   123          model.13.m.0.m.1.cv1.bn.weight         BatchNorm2d      True         128               [128]     0.911     0.157        float32
#   123            model.13.m.0.m.1.cv1.bn.bias         BatchNorm2d      True         128               [128]    -0.756     0.458        float32
#   124        model.13.m.0.m.1.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000124   0.00566        float32
#   125          model.13.m.0.m.1.cv2.bn.weight         BatchNorm2d      True         128               [128]      1.12      0.22        float32
#   125            model.13.m.0.m.1.cv2.bn.bias         BatchNorm2d      True         128               [128]     0.324     0.426        float32
#   126                                model.14            Upsample     False           0                  []         -         -              -
#   127                                model.15              Concat     False           0                  []         -         -              -
#   128                model.16.cv1.conv.weight              Conv2d      True      262144   [256, 1024, 1, 1] -0.000394   0.00878        float32
#   129                  model.16.cv1.bn.weight         BatchNorm2d      True         256               [256]     0.513     0.163        float32
#   129                    model.16.cv1.bn.bias         BatchNorm2d      True         256               [256]    -0.242      0.83        float32
#   130                model.16.cv2.conv.weight              Conv2d      True       98304    [256, 384, 1, 1] -0.000368      0.01        float32
#   131                  model.16.cv2.bn.weight         BatchNorm2d      True         256               [256]     0.582     0.229        float32
#   131                    model.16.cv2.bn.bias         BatchNorm2d      True         256               [256]    -0.423      0.79        float32
#   132            model.16.m.0.cv1.conv.weight              Conv2d      True        8192     [64, 128, 1, 1]  -0.00176    0.0196        float32
#   133              model.16.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]     0.309     0.127        float32
#   133                model.16.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]    -0.175     0.504        float32
#   134            model.16.m.0.cv2.conv.weight              Conv2d      True        8192     [64, 128, 1, 1] -0.000565    0.0103        float32
#   135              model.16.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]      1.35     0.142        float32
#   135                model.16.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]    -0.181     0.205        float32
#   136            model.16.m.0.cv3.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]  -0.00122     0.013        float32
#   137              model.16.m.0.cv3.bn.weight         BatchNorm2d      True         128               [128]     0.685     0.201        float32
#   137                model.16.m.0.cv3.bn.bias         BatchNorm2d      True         128               [128]     -0.36     0.491        float32
#   138        model.16.m.0.m.0.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000801    0.0119        float32
#   139          model.16.m.0.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]      0.86     0.148        float32
#   139            model.16.m.0.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]    -0.705     0.617        float32
#   140        model.16.m.0.m.0.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000801    0.0108        float32
#   141          model.16.m.0.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]     0.767     0.146        float32
#   141            model.16.m.0.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]    -0.321     0.543        float32
#   142        model.16.m.0.m.1.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000774    0.0103        float32
#   143          model.16.m.0.m.1.cv1.bn.weight         BatchNorm2d      True          64                [64]     0.751     0.136        float32
#   143            model.16.m.0.m.1.cv1.bn.bias         BatchNorm2d      True          64                [64]    -0.536     0.564        float32
#   144        model.16.m.0.m.1.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3]  -0.00016   0.00961        float32
#   145          model.16.m.0.m.1.cv2.bn.weight         BatchNorm2d      True          64                [64]      1.25     0.264        float32
#   145            model.16.m.0.m.1.cv2.bn.bias         BatchNorm2d      True          64                [64]     0.642     0.717        float32
#   146                                model.17            Upsample     False           0                  []         -         -              -
#   147                                model.18              Concat     False           0                  []         -         -              -
#   148                model.19.cv1.conv.weight              Conv2d      True       65536    [128, 512, 1, 1] -1.29e-05    0.0256        float32
#   149                  model.19.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   149                    model.19.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   150                model.19.cv2.conv.weight              Conv2d      True       24576    [128, 192, 1, 1] -9.95e-05    0.0417        float32
#   151                  model.19.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   151                    model.19.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   152            model.19.m.0.cv1.conv.weight              Conv2d      True        2048      [32, 64, 1, 1] -0.000166     0.072        float32
#   153              model.19.m.0.cv1.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   153                model.19.m.0.cv1.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   154            model.19.m.0.cv2.conv.weight              Conv2d      True        2048      [32, 64, 1, 1]  -0.00099    0.0723        float32
#   155              model.19.m.0.cv2.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   155                model.19.m.0.cv2.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   156            model.19.m.0.cv3.conv.weight              Conv2d      True        4096      [64, 64, 1, 1] -0.000755    0.0723        float32
#   157              model.19.m.0.cv3.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   157                model.19.m.0.cv3.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   158        model.19.m.0.m.0.cv1.conv.weight              Conv2d      True        9216      [32, 32, 3, 3]  0.000258    0.0343        float32
#   159          model.19.m.0.m.0.cv1.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   159            model.19.m.0.m.0.cv1.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   160        model.19.m.0.m.0.cv2.conv.weight              Conv2d      True        9216      [32, 32, 3, 3]  0.000299    0.0339        float32
#   161          model.19.m.0.m.0.cv2.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   161            model.19.m.0.m.0.cv2.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   162        model.19.m.0.m.1.cv1.conv.weight              Conv2d      True        9216      [32, 32, 3, 3]  -0.00011     0.034        float32
#   163          model.19.m.0.m.1.cv1.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   163            model.19.m.0.m.1.cv1.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   164        model.19.m.0.m.1.cv2.conv.weight              Conv2d      True        9216      [32, 32, 3, 3]   0.00129    0.0341        float32
#   165          model.19.m.0.m.1.cv2.bn.weight         BatchNorm2d      True          32                [32]         1         0        float32
#   165            model.19.m.0.m.1.cv2.bn.bias         BatchNorm2d      True          32                [32]         0         0        float32
#   166                    model.20.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -3.12e-05     0.017        float32
#   167                      model.20.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   167                        model.20.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   168                                model.21              Concat     False           0                  []         -         -              -
#   169                model.22.cv1.conv.weight              Conv2d      True       98304    [256, 384, 1, 1] -0.000103    0.0294        float32
#   170                  model.22.cv1.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   170                    model.22.cv1.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   171                model.22.cv2.conv.weight              Conv2d      True       98304    [256, 384, 1, 1]  6.82e-05    0.0295        float32
#   172                  model.22.cv2.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   172                    model.22.cv2.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   173            model.22.m.0.cv1.conv.weight              Conv2d      True        8192     [64, 128, 1, 1]  0.000361    0.0511        float32
#   174              model.22.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   174                model.22.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   175            model.22.m.0.cv2.conv.weight              Conv2d      True        8192     [64, 128, 1, 1]  0.000573    0.0512        float32
#   176              model.22.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   176                model.22.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   177            model.22.m.0.cv3.conv.weight              Conv2d      True       16384    [128, 128, 1, 1] -0.000316    0.0509        float32
#   178              model.22.m.0.cv3.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   178                model.22.m.0.cv3.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   179        model.22.m.0.m.0.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -0.000114     0.024        float32
#   180          model.22.m.0.m.0.cv1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   180            model.22.m.0.m.0.cv1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   181        model.22.m.0.m.0.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3]  2.73e-05    0.0241        float32
#   182          model.22.m.0.m.0.cv2.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   182            model.22.m.0.m.0.cv2.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   183        model.22.m.0.m.1.cv1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3]  0.000105    0.0241        float32
#   184          model.22.m.0.m.1.cv1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   184            model.22.m.0.m.1.cv1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   185        model.22.m.0.m.1.cv2.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -4.98e-05    0.0241        float32
#   186          model.22.m.0.m.1.cv2.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   186            model.22.m.0.m.1.cv2.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   187                    model.23.conv.weight              Conv2d      True      589824    [256, 256, 3, 3] -3.43e-05     0.012        float32
#   188                      model.23.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   188                        model.23.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   189                                model.24              Concat     False           0                  []         -         -              -
#   190                model.25.cv1.conv.weight              Conv2d      True      393216    [512, 768, 1, 1]  1.79e-05    0.0208        float32
#   191                  model.25.cv1.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   191                    model.25.cv1.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   192                model.25.cv2.conv.weight              Conv2d      True      393216    [512, 768, 1, 1] -1.35e-05    0.0208        float32
#   193                  model.25.cv2.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   193                    model.25.cv2.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   194            model.25.m.0.cv1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]  -1.9e-05     0.036        float32
#   195              model.25.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   195                model.25.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   196            model.25.m.0.cv2.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]  8.89e-05    0.0362        float32
#   197              model.25.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   197                model.25.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   198            model.25.m.0.cv3.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -1.39e-05    0.0362        float32
#   199              model.25.m.0.cv3.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   199                model.25.m.0.cv3.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   200        model.25.m.0.m.0.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -2.83e-05     0.017        float32
#   201          model.25.m.0.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   201            model.25.m.0.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   202        model.25.m.0.m.0.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3]  7.66e-05     0.017        float32
#   203          model.25.m.0.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   203            model.25.m.0.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   204        model.25.m.0.m.1.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -2.77e-05     0.017        float32
#   205          model.25.m.0.m.1.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   205            model.25.m.0.m.1.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   206        model.25.m.0.m.1.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3]   1.1e-05     0.017        float32
#   207          model.25.m.0.m.1.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   207            model.25.m.0.m.1.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   208                    model.26.conv.weight              Conv2d      True  2.3593e+06    [512, 512, 3, 3]  1.98e-06    0.0085        float32
#   209                      model.26.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   209                        model.26.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   210                                model.27              Concat     False           0                  []         -         -              -
#   211                model.28.cv1.conv.weight              Conv2d      True      524288   [512, 1024, 1, 1] -2.48e-05    0.0181        float32
#   212                  model.28.cv1.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   212                    model.28.cv1.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   213                model.28.cv2.conv.weight              Conv2d      True      393216    [512, 768, 1, 1] -2.42e-05    0.0208        float32
#   214                  model.28.cv2.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   214                    model.28.cv2.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   215            model.28.m.0.cv1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1] -0.000125    0.0362        float32
#   216              model.28.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   216                model.28.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   217            model.28.m.0.cv2.conv.weight              Conv2d      True       32768    [128, 256, 1, 1]  0.000292    0.0361        float32
#   218              model.28.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   218                model.28.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   219            model.28.m.0.cv3.conv.weight              Conv2d      True       65536    [256, 256, 1, 1] -0.000166    0.0361        float32
#   220              model.28.m.0.cv3.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   220                model.28.m.0.cv3.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   221        model.28.m.0.m.0.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -4.66e-06     0.017        float32
#   222          model.28.m.0.m.0.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   222            model.28.m.0.m.0.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   223        model.28.m.0.m.0.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -6.14e-05     0.017        float32
#   224          model.28.m.0.m.0.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   224            model.28.m.0.m.0.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   225        model.28.m.0.m.1.cv1.conv.weight              Conv2d      True      147456    [128, 128, 3, 3] -0.000115     0.017        float32
#   226          model.28.m.0.m.1.cv1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   226            model.28.m.0.m.1.cv1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   227        model.28.m.0.m.1.cv2.conv.weight              Conv2d      True      147456    [128, 128, 3, 3]  1.11e-05     0.017        float32
#   228          model.28.m.0.m.1.cv2.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   228            model.28.m.0.m.1.cv2.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   229            model.29.cv2.0.0.conv.weight              Conv2d      True       73728     [64, 128, 3, 3] -2.75e-05     0.017        float32
#   230              model.29.cv2.0.0.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   230                model.29.cv2.0.0.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   231            model.29.cv2.0.1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3]  0.000224    0.0241        float32
#   232              model.29.cv2.0.1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   232                model.29.cv2.0.1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   233                 model.29.cv2.0.2.weight              Conv2d      True        4096      [64, 64, 1, 1] -0.000227    0.0728        float32
#   233                   model.29.cv2.0.2.bias              Conv2d      True          64                [64]         2         0        float32
#   234            model.29.cv2.1.0.conv.weight              Conv2d      True      147456     [64, 256, 3, 3] -1.79e-06    0.0121        float32
#   235              model.29.cv2.1.0.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   235                model.29.cv2.1.0.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   236            model.29.cv2.1.1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3]  -5.7e-05     0.024        float32
#   237              model.29.cv2.1.1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   237                model.29.cv2.1.1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   238                 model.29.cv2.1.2.weight              Conv2d      True        4096      [64, 64, 1, 1]  6.39e-05    0.0718        float32
#   238                   model.29.cv2.1.2.bias              Conv2d      True          64                [64]         2         0        float32
#   239            model.29.cv2.2.0.conv.weight              Conv2d      True      294912     [64, 512, 3, 3]  1.46e-06   0.00851        float32
#   240              model.29.cv2.2.0.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   240                model.29.cv2.2.0.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   241            model.29.cv2.2.1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -9.25e-05    0.0241        float32
#   242              model.29.cv2.2.1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   242                model.29.cv2.2.1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   243                 model.29.cv2.2.2.weight              Conv2d      True        4096      [64, 64, 1, 1] -0.000223    0.0716        float32
#   243                   model.29.cv2.2.2.bias              Conv2d      True          64                [64]         2         0        float32
#   244            model.29.cv2.3.0.conv.weight              Conv2d      True      294912     [64, 512, 3, 3]  1.46e-05   0.00851        float32
#   245              model.29.cv2.3.0.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   245                model.29.cv2.3.0.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   246            model.29.cv2.3.1.conv.weight              Conv2d      True       36864      [64, 64, 3, 3] -4.32e-05     0.024        float32
#   247              model.29.cv2.3.1.bn.weight         BatchNorm2d      True          64                [64]         1         0        float32
#   247                model.29.cv2.3.1.bn.bias         BatchNorm2d      True          64                [64]         0         0        float32
#   248                 model.29.cv2.3.2.weight              Conv2d      True        4096      [64, 64, 1, 1]  -0.00131    0.0733        float32
#   248                   model.29.cv2.3.2.bias              Conv2d      True          64                [64]         2         0        float32
#   249          model.29.cv3.0.0.0.conv.weight              Conv2d      True        1152      [128, 1, 3, 3]  -0.00187     0.195        float32
#   250            model.29.cv3.0.0.0.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   250              model.29.cv3.0.0.0.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   251          model.29.cv3.0.0.1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]  0.000455    0.0513        float32
#   252            model.29.cv3.0.0.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   252              model.29.cv3.0.0.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   253          model.29.cv3.0.1.0.conv.weight              Conv2d      True        1152      [128, 1, 3, 3]  -0.00487     0.195        float32
#   254            model.29.cv3.0.1.0.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   254              model.29.cv3.0.1.0.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   255          model.29.cv3.0.1.1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1] -0.000581    0.0511        float32
#   256            model.29.cv3.0.1.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   256              model.29.cv3.0.1.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   257                 model.29.cv3.0.2.weight              Conv2d      True         128      [1, 128, 1, 1]    0.0056    0.0483        float32
#   257                   model.29.cv3.0.2.bias              Conv2d      True           1                 [1]     -8.54       nan        float32
#   258          model.29.cv3.1.0.0.conv.weight              Conv2d      True        2304      [256, 1, 3, 3] -0.000381     0.196        float32
#   259            model.29.cv3.1.0.0.bn.weight         BatchNorm2d      True         256               [256]         1         0        float32
#   259              model.29.cv3.1.0.0.bn.bias         BatchNorm2d      True         256               [256]         0         0        float32
#   260          model.29.cv3.1.0.1.conv.weight              Conv2d      True       32768    [128, 256, 1, 1] -0.000359    0.0361        float32
#   261            model.29.cv3.1.0.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   261              model.29.cv3.1.0.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   262          model.29.cv3.1.1.0.conv.weight              Conv2d      True        1152      [128, 1, 3, 3]  -0.00202     0.189        float32
#   263            model.29.cv3.1.1.0.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   263              model.29.cv3.1.1.0.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   264          model.29.cv3.1.1.1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1] -0.000258    0.0509        float32
#   265            model.29.cv3.1.1.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   265              model.29.cv3.1.1.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   266                 model.29.cv3.1.2.weight              Conv2d      True         128      [1, 128, 1, 1]  -0.00659    0.0454        float32
#   266                   model.29.cv3.1.2.bias              Conv2d      True           1                 [1]     -7.15       nan        float32
#   267          model.29.cv3.2.0.0.conv.weight              Conv2d      True        4608      [512, 1, 3, 3]  -0.00149     0.193        float32
#   268            model.29.cv3.2.0.0.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   268              model.29.cv3.2.0.0.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   269          model.29.cv3.2.0.1.conv.weight              Conv2d      True       65536    [128, 512, 1, 1] -0.000203    0.0255        float32
#   270            model.29.cv3.2.0.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   270              model.29.cv3.2.0.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   271          model.29.cv3.2.1.0.conv.weight              Conv2d      True        1152      [128, 1, 3, 3]  0.000868     0.193        float32
#   272            model.29.cv3.2.1.0.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   272              model.29.cv3.2.1.0.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   273          model.29.cv3.2.1.1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]   0.00011    0.0512        float32
#   274            model.29.cv3.2.1.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   274              model.29.cv3.2.1.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   275                 model.29.cv3.2.2.weight              Conv2d      True         128      [1, 128, 1, 1]   0.00301    0.0519        float32
#   275                   model.29.cv3.2.2.bias              Conv2d      True           1                 [1]     -5.77       nan        float32
#   276          model.29.cv3.3.0.0.conv.weight              Conv2d      True        4608      [512, 1, 3, 3]   0.00244     0.192        float32
#   277            model.29.cv3.3.0.0.bn.weight         BatchNorm2d      True         512               [512]         1         0        float32
#   277              model.29.cv3.3.0.0.bn.bias         BatchNorm2d      True         512               [512]         0         0        float32
#   278          model.29.cv3.3.0.1.conv.weight              Conv2d      True       65536    [128, 512, 1, 1]  7.05e-05    0.0255        float32
#   279            model.29.cv3.3.0.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   279              model.29.cv3.3.0.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   280          model.29.cv3.3.1.0.conv.weight              Conv2d      True        1152      [128, 1, 3, 3]  -0.00742     0.191        float32
#   281            model.29.cv3.3.1.0.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   281              model.29.cv3.3.1.0.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   282          model.29.cv3.3.1.1.conv.weight              Conv2d      True       16384    [128, 128, 1, 1]  0.000536    0.0508        float32
#   283            model.29.cv3.3.1.1.bn.weight         BatchNorm2d      True         128               [128]         1         0        float32
#   283              model.29.cv3.3.1.1.bn.bias         BatchNorm2d      True         128               [128]         0         0        float32
#   284                 model.29.cv3.3.2.weight              Conv2d      True         128      [1, 128, 1, 1]   0.00147    0.0488        float32
#   284                   model.29.cv3.3.2.bias              Conv2d      True           1                 [1]     -4.38       nan        float32
#   285                model.29.dfl.conv.weight              Conv2d     False          16       [1, 16, 1, 1]       7.5      4.76        float32
# /usr/local/lib/python3.13/dist-packages/ultralytics/utils/torch_utils.py:555: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1858.)
#   f"{i:>5g}{f'{mn}.{pn}':>40}{mt:>20}{p.requires_grad!r:>10}{p.numel():>12g}{list(p.shape)!s:>20}{p.mean():>10.3g}{p.std():>10.3g}{str(p.dtype).replace('torch.', ''):>15}"
# YOLO11-p2 summary: 286 layers, 20,550,356 parameters, 20,550,340 gradients, 88.4 GFLOPs
# (286, 20550356, 20550340, 88.3526144)

# %% [markdown]
# ## 2. Sanity Training Run V2

# %%
import time

print("Starting 3-Epoch Sanity Run V2 (Batch=16, 640x640)...")
t0 = time.time()

results = model.train(
    data='dataset_yolo_single_class/data.yaml',
    epochs=3,
    imgsz=640,
    batch=16,
    name='EXP16-SanityV2-YOLO11m-P2',
    cache=False,
    amp=True,
    exist_ok=True
)

t1 = time.time()
print(f"\nSanity Run V2 Complete in {t1 - t0:.2f} seconds.")
# Out:
# Starting 3-Epoch Sanity Run V2 (Batch=16, 640x640)...
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_yolo_single_class/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11-p2.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=EXP16-SanityV2-YOLO11m-P2, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.9MB/s 0.0s
# WARNING ⚠️ no model scale passed. Assuming scale='m'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  24            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  25                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  26                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  27            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  28                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  29    [19, 22, 25, 28]  1   1245588  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512, 512]]
# YOLO11-p2 summary: 286 layers, 20,550,356 parameters, 20,550,340 gradients, 88.4 GFLOPs
#
# Transferred 803/803 items from pretrained weights
# Freezing layer 'model.29.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.6±0.2 ms, read: 0.2±0.1 MB/s, size: 53.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# train: Scanning /content/drive/MyDrive/sem_defect_project/dataset_yolo_single_class/train/labels.cache... 1046 images, 13 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1046/1046 175.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.7±0.3 ms, read: 0.1±0.1 MB/s, size: 44.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /content/drive/MyDrive/sem_defect_project/dataset_yolo_single_class/valid/labels.cache... 31 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 31/31 1.9Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 131 weight(decay=0.0), 140 weight(decay=0.0005), 139 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2/labels.jpg...
# Using 1046 train, 31 val images for fraction=1.0 at imgsz=640
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3        12G      2.676       3.02      3.581         40        640: 100% ━━━━━━━━━━━━ 66/66 8.7s/it 9:312.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 35.4s/it 35.4s
#                    all         31        184     0.0049     0.0326   0.000353   7.47e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3      11.9G      2.095      2.176      2.572         22        640: 100% ━━━━━━━━━━━━ 66/66 1.2it/s 55.9s0.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all         31        184      0.139      0.402      0.117     0.0456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3        12G      1.874      1.929      2.291         32        640: 100% ━━━━━━━━━━━━ 66/66 1.2it/s 54.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all         31        184      0.511      0.511      0.456      0.239
#
# 3 epochs completed in 0.205 hours.
# Optimizer stripped from /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2/weights/last.pt, 41.7MB
# Optimizer stripped from /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2/weights/best.pt, 41.7MB
#
# Validating /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2/weights/best.pt...
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11-p2 summary (fused): 155 layers, 20,526,228 parameters, 0 gradients, 87.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7s/it 6.7s
#                    all         31        184      0.511      0.516      0.461      0.239
# Speed: 0.2ms preprocess, 200.7ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/drive/MyDrive/sem_defect_project/runs/detect/EXP16-SanityV2-YOLO11m-P2
#
# Sanity Run V2 Complete in 788.49 seconds.

# %%
# Print Peak VRAM Usage
print("\n=== TESLA T4 VRAM USAGE ===")
# !nvidia-smi --query-gpu=memory.used,memory.total --format=csv
# Out:
# === TESLA T4 VRAM USAGE ===
# memory.used [MiB], memory.total [MiB]
# 1737 MiB, 15360 MiB

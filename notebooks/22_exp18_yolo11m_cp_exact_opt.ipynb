# %% [markdown]
# # Phase 18: YOLO11m + Copy-Paste (EXACT EXP-10 Optimizer)
#
# This notebook trains the standard YOLO11m model on the augmented `dataset_yolo_single_class_cp` dataset using the EXACT same hyperparameter configuration as the EXP-10 baseline (`AdamW`, `lr0=0.001`, `weight_decay=0.01`, `patience=50`).

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install dependencies
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 6.9 MB/s eta 0:00:00
# ...

# %%
import os
import torch
from ultralytics import YOLO

PROJECT_ROOT = '/content/drive/MyDrive/sem_defect_project'
os.chdir(PROJECT_ROOT)
print(f"Current working directory: {os.getcwd()}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Current working directory: /content/drive/MyDrive/sem_defect_project
# CUDA Available: True
# GPU Device: Tesla T4

# %% [markdown]
# ## 1. Load YOLO11m (Official Weights)

# %%
# Instantiate standard YOLO11m using official pretrained weights
print("Instantiating standard YOLO11m model...")
model = YOLO('yolo11m.pt')
# Out:
# Instantiating standard YOLO11m model...

# %% [markdown]
# ## 2. FULL Training Run (EXACT EXP-10 HYPERPARAMETERS)

# %%
import time

print("Starting FULL Run on CP Dataset (Batch=16, 640x640, Epochs=200)...")
print("Enforcing EXP-10 Exact Optimizer: AdamW, lr0=0.001, weight_decay=0.01, patience=50")

t0 = time.time()

results = model.train(
    data='datasets/dataset_yolo_single_class_cp/data.yaml',
    epochs=200,
    patience=50,
    imgsz=640,
    batch=16,
    optimizer='AdamW',
    lr0=0.001,
    weight_decay=0.01,
    name='EXP18-YOLO11m-CP-Exact-Opt',
    cache=False,
    amp=True,
    exist_ok=True
)

t1 = time.time()
print(f"\nFull Run Complete in {(t1 - t0)/3600:.2f} hours.")
print("Best weights saved to: runs/detect/EXP18-YOLO11m-CP-Exact-Opt/weights/best.pt")
# Out:
# Starting FULL Run on CP Dataset (Batch=16, 640x640, Epochs=200)...
# Enforcing EXP-10 Exact Optimizer: AdamW, lr0=0.001, weight_decay=0.01, patience=50
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
